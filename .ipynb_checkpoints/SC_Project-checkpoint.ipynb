# %% [markdown]
# # Social Graph Project

# %% [markdown]
# Link to data : https://networkrepository.com/soc-twitter-follows.php

# %%
# %matplotlib inline

from scipy.io import mmread
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
a = mmread('data\soc-twitter-follows')
graph = nx.Graph(a)

# G = nx.read_edgelist("data\soc-twitter-follows.mtx")

# %%
number_of_nodes = len(graph.nodes())

# %%
len(graph.edges())
# Out:
# 713319

# %%
# nx.draw(graph, with_labels=True)
# plt.show()

# %%
average_degree = sum(dict(graph.degree()).values()) / number_of_nodes
average_degree
# Out:
# 3.5250087097467624

# %%
p = average_degree / (number_of_nodes -1)
p
# Out:
# 8.709789803633053e-06

# %%
deg_seq = [graph.degree(x) for x in nx.nodes(graph)]
plt.hist(deg_seq)
plt.title('Degree Histogram')
plt.xlabel('degree')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# Create a random graph who has the same number of node and average degree

# %%
clustering_coefficients = nx.clustering(graph)

# Plotting the histogram
# plt.figure(figsize=(8, 6))
plt.hist(list(clustering_coefficients.values()))
plt.title('Clustering Coefficients Histogram')
plt.xlabel('Clustering Coefficient')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
average_clustering_coefficient = nx.average_clustering(graph)
average_clustering_coefficient
# Out:
# 0.014446298395106846

# %% [markdown]
# ### • Draw the histogram of distances in the graphs, the diameter and the average distance. Compare with random graphs and discuss the results.

# %%
all_distances = []
for node in graph.nodes():
    distances = nx.shortest_path_length(graph, node)
    all_distances.extend(list(distances.values()))

# Plotting the histogram of distances
plt.hist(all_distances)
plt.title('Histogram of Distances in the Graph')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Calculate diameter and average distance
diameter = nx.diameter(G)
average_distance = nx.average_shortest_path_length(G)

# Print the diameter and average distance
print(f'Diameter: {diameter}')
print(f'Average Distance: {average_distance}')
